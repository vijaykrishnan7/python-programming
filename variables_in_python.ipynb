# %% [markdown]
# #**variables in python**
# * a variable is a name refer to a value stored data values.
# * you can assing values using the '=' operator.python is dynamically typed
#
# variables are containers for storing data values

# %% [markdown]
# #rules for naming varibales

# %% [markdown]
# 1.must be start with a letter or underscore _
#
# 2.cannot start with a number
#
# 3.can contain letter ,digits,and underscoress
#
# 4.case-sensitive(Name=!name)
#
# 5.should not use python keywords (if,for,class,etc.)

# %% [markdown]
# #examples

# %%
x=10
name ='alice'
_price = 99.99
is_active=True
print(x,name,_price,is_active)
print(type(x),type(_price))
# Out:
# 10 alice 99.99 True
# <class 'int'> <class 'float'>

# %%
name='vijay'
name
print(name)
print('name')
print('my name is ',name)
print('my name is ',name,"and everyone call me",name)
# Out:
# vijay
# name
# my name is  vijay
# my name is  vijay and everyone call me vijay

# %% [markdown]
# # new section

# %%
name = "vijay"
gender ="male"
height = 173
course="bsc cs"
colleg="cas ihrd"
university="cu"
fav_food="biriyani"
fav_color="black"
fav_place="home"
frnd="vt"
fav_animal="dog"
home_town="kozhikode"
nationality="indian"
fav_sport="badminton"
fav_player="cr7"
print("my name is",name,nationality,home_town,)
# Out:
# my name is vijay indian kozhikode

# %%
x=3+1j
com=1+0j
print(com)
print(x)
print(type(x))
# Out:
# (1+0j)
# (3+1j)
# <class 'complex'>

# %%
x=None
print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# # string-sequence of characters

# %%
s1='hello'
s2="world"
s3="""this multiline string"""
print(s1,s2)
print(s1+s2)
print(s3)
# Out:
# hello world
# helloworld
# this multiline string

# %% [markdown]
# # index

# %%
word="python"
print(word[0])
print(word[2])
# Out:
# p
# t

# %% [markdown]
# # string slicing

# %%
word="python"
word[0:3]
word[::2]
# Out:
# 'pto'

# %% [markdown]
# # indexing and slicing

# %%
s="ppython"
print("s[0]=",s[0])
print("s[-1]=",s[1])
print("s[1:4]", s[1:4])
print("s[:3]=",s[::3])
print("s[::2]=",s[::2])
print("reverse:",s[::-1])
# Out:
# s[0]= p
# s[-1]= p
# s[1:4] pyt
# s[:3]= ptn
# s[::2]= pyhn
# reverse: nohtypp

# %%
vijay="sos|vijay krishnan |Data science and analytics|july2026|morning|offline"
print(vijay[4:9]+ vijay[10:18]+vijay[20]+vijay[25]+vijay[33]+vijay[36]+vijay[]+vijay[47:51])
# Out:
#   Cell In[10], line 2
#     print(vijay[4:9]+ vijay[10:18]+vijay[20]+vijay[25]+vijay[33]+vijay[36]+vijay[]+vijay[47:51])
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
vijay="iam ronaldo"
print(vijay.upper())
print(vijay.lower())
print(vijay.title())
print(vijay.swapcase())
print(vijay.capitalize())
# Out:
# IAM RONALDO
# iam ronaldo
# Iam Ronaldo
# IAM RONALDO
# Iam ronaldo

# %%
text="vijay"
print(len(text))
print(text.find("v"))
# Out:
# 5
# 0

# %% [markdown]
# # split

# %%
vijay="i iam ronaldo"
print(vijay.split())
# Out:
# ['i', 'iam', 'ronaldo']

# %% [markdown]
# # replace and translate

# %%
vijay="ronaldo is good"
print(vijay.replace("good","goat"))
# Out:
# ronaldo is goat

# %%
tr=str.maketrans("aeiou","12345")
print("translate","education".translate(tr))
# Out:
# translate 2d5c1t34n

# %%
baa="iam\nvijay"
print(baa)
# Out:
# iam
# vijay

# %%
x=123
print(type(x))

y=str(x)
print(y)
print(type(y))
# Out:
# <class 'int'>
# 123
# <class 'str'>

# %% [markdown]
# float division
# modulus
# exponential
# # floor division

# %% [markdown]
# flooor division means that dividinng two numbers and removing the point values and  rounding the result to whole number

# %%
a=10
b=3
print(a//b)
# Out:
# 3

# %% [markdown]
# # modulus

# %% [markdown]
# it is an arithematic operator in python that returns reminder after division

# %%
a=5
b=2
print(a%b)
# Out:
# 1

# %% [markdown]
# # exponential

# %% [markdown]
# it means that raising a number to a power
# it uses ** operator

# %%
a=5
b=2
print(a**b)
# Out:
# 25

# %%
x=10
y=5
print(x==y)
print(x!=y)
# Out:
# False
# True

# %% [markdown]
# # list in python

# %%
my_list =[1,2,3,4,5]
my_list

fruit=["apple","orange"] #odered list
fruit

fruit=["apple","orange","apple"] #allows duplicates
fruit

vijay=[1,"hari",3.12,True] #heterogineous can store any data
vijay
vijay[0]
vijay[0]=100
vijay
# Out:
# [100, 'hari', 3.12, True]

# %% [markdown]
# lists are ordered,mutable ncollections used to store multiple items in a single varibale
#
#
# properties
#
# ordered
# allow duplicates
# mutable
